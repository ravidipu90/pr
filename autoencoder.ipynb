# %%
import os
import torch 
import torchvision
import torch.nn as nn
import torchvision.transforms as transforms
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data.sampler import SubsetRandomSampler

from PIL import Image
import numpy as np

import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt 

from tqdm import tqdm


device = torch.device("cuda:7" if torch.cuda.is_available() else "cpu")

# %%
class Config(object):
    def __init__(self):
        self.name = 'Autoencoder'
        self.dataset_name = 'MNIST'
        
        self.save_path = './checkpoint/'+ self.name
        self.model_path = self.save_path + '/models'
        self.decode_path = self.save_path + '/decoded_results'
        self.val_path = self.save_path + '/val_results'
        self.test_path = self.save_path + '/test_results'
        
    
        self.batch_size = 64
        self.max_epochs = 100
        self.lr = 1e-3 
        self.weight_decay = 1e-4
        self.save_every = 1     #epoch

        
    
        os.makedirs(self.save_path, exist_ok=True)
        os.makedirs(self.model_path, exist_ok=True)
        os.makedirs(self.decode_path, exist_ok=True)
        os.makedirs(self.val_path, exist_ok=True)
        os.makedirs(self.test_path, exist_ok=True)
        
opt = Config()

# %%
def get_train_valid_loader(batch_size,
                           random_seed,
                           valid_size=0.2,
                           shuffle=True,
                           num_workers=1,
                           pin_memory=True):
    
    error_msg = "[!] valid_size should be in the range [0, 1]."
    assert ((valid_size >= 0) and (valid_size <= 1)), error_msg

    normalize = transforms.Normalize((0.1307,), (0.3081,))  # MNIST

    # define transforms
    transform = transforms.Compose([transforms.ToTensor(),normalize])
    
    
    # load the dataset
    train_dataset = torchvision.datasets.MNIST(root='./dataset/MNIST',train=True, download=True,transform=transform)

    valid_dataset = torchvision.datasets.MNIST(root='./dataset/MNIST',train=True, download=True,transform=transform)

    num_train = len(train_dataset)
    indices = list(range(num_train))
    split = int(np.floor(valid_size * num_train))

    if shuffle == True:
        np.random.seed(random_seed)
        np.random.shuffle(indices)

    train_idx, valid_idx = indices[split:], indices[:split]

    train_sampler = SubsetRandomSampler(train_idx)
    valid_sampler = SubsetRandomSampler(valid_idx)

    train_loader = torch.utils.data.DataLoader(train_dataset,batch_size=opt.batch_size, sampler=train_sampler, 
                    num_workers=num_workers, pin_memory=pin_memory)

    valid_loader = torch.utils.data.DataLoader(valid_dataset,batch_size=opt.batch_size, sampler=valid_sampler, 
                    num_workers=num_workers, pin_memory=pin_memory)


    
    return (train_loader, valid_loader)
    
def get_test_loader(batch_size,
                    shuffle=True,
                    num_workers=1,
                    pin_memory=True):
    
    normalize = transforms.Normalize((0.1307,), (0.3081,))  # MNIST

    # define transform
    transform = transforms.Compose([transforms.ToTensor(),normalize])

    dataset = torchvision.datasets.MNIST(root='./dataset/MNIST',train=False,download=True,transform=transform)

    data_loader = torch.utils.data.DataLoader(dataset,batch_size=opt.batch_size, shuffle=shuffle, 
                                              num_workers=num_workers,pin_memory=pin_memory)

    return data_loader,dataset

# %%
train_loader,val_loader = get_train_valid_loader(opt.batch_size,random_seed=24)
test_loader,dataset = get_test_loader(opt.batch_size)

# %%
class Autoencoder(nn.Module):
    def __init__(self):
        super(Autoencoder, self).__init__()

        #Encoder
        self.enc1 = nn.Linear(in_features=784, out_features=256) # Input image (28*28 = 784)
        self.enc2 = nn.Linear(in_features=256, out_features=128)
        self.enc3 = nn.Linear(in_features=128, out_features=64)
        

        #Decoder 
        self.dec1 = nn.Linear(in_features=64, out_features=128)
        self.dec2 = nn.Linear(in_features=128, out_features=256)
        self.dec3 = nn.Linear(in_features=256, out_features=784) # Output image (28*28 = 784)

    def forward(self, x):
        x = F.relu(self.enc1(x))
        x = F.relu(self.enc2(x))
        x = F.relu(self.enc3(x))

        x = F.relu(self.dec1(x))
        x = F.relu(self.dec2(x))
        x = F.relu(self.dec3(x))

        return x

# %%
def train_autoencoder(**kwargs):
    torch.cuda.empty_cache()
    opt = Config()
    
    autoencoder = Autoencoder()
    autoencoder=autoencoder.to(device)
    optimizer = optim.Adam(autoencoder.parameters(), lr=opt.lr, weight_decay=opt.weight_decay)
    criterion = nn.MSELoss()
    
    
    try:
        state = torch.load(os.path.join(opt.model_path, 'autoencoder.pth'))
        autoencoder.load_state_dict(state['state_dict'])
        print("Loaded pre-trained autoencoder with success.")
        e_counter=state['epoch']
        best_valid_loss = state['valid_loss_min']
        print('val loss till yet :',best_valid_loss)
        print('Previously Trained for {} epoches'.format(e_counter))
        e_counter += 1
    except FileNotFoundError:
        print("Pre-trained weights of integrated autoencoder not found. Training from scratch.")
        e_counter=0
        best_valid_loss = float('inf')
        
    train_loss = []
    val_loss=[]
    epoches=[]
    
    for epoch in range(e_counter,opt.max_epochs):
        autoencoder.train()
        print()
        print('==================================================================')
        print('-------------Epoch: {}/{}------------'.format(epoch,opt.max_epochs))
        epoch_loss=0.0
        for idx,(data,_) in enumerate(train_loader,0):
            
            data = data.to(device)
            optimizer.zero_grad()
            
            data = data.view(data.size(0),-1)
            output = autoencoder(data)
            
            loss = criterion(output, data)
            loss.backward()
            optimizer.step()
            
            epoch_loss+=loss.item()
            
            if (idx+1)%200 == 0:
                print('Batch ',idx,'/',len(train_loader),'|| Loss: %.4f '%(epoch_loss/(idx+1)))

                               
        mean_loss = epoch_loss / len(train_loader)
        train_loss.append(mean_loss)
        with open('auto_logs.txt', 'a') as file:
            file.write('epoch: ' + str(epoch) + ', train loss: ' + str(mean_loss) + '\n')
        
    
        print()    
        print('...........................validation....................................')
        autoencoder.eval()
        eval_loss = 0.0

        with torch.no_grad():
            for idx,(data,_) in enumerate(val_loader):
                data = data.to(device)
                data = data.view(data.size(0),-1)
                output = autoencoder.forward(data)
                v_loss = criterion(output, data)
                eval_loss += v_loss.item()
                
                if (idx+1)%90 == 0:
                    print('Batch ',idx,'/',len(val_loader),'|| Loss: %.4f'%(eval_loss/(idx+1)))
                
        valid_loss = eval_loss/len(val_loader)
        val_loss.append(valid_loss)
        epoches.append(epoch)
        print('Train Loss: %.4f || Valid Loss: %.4f '%(mean_loss,valid_loss))
        with open('auto_logs.txt', 'a') as file:
            file.write('epoch: '+ str(epoch)+', validation loss: '+str(valid_loss)+'\n')
        
        state = {
                'epoch': epoch,
                'valid_loss_min': valid_loss,
                'state_dict': autoencoder.state_dict(),
                'optimizer': optimizer.state_dict()
                }
        
        if epoch % opt.save_every == 0 or epoch == opt.max_epochs - 1:
            if valid_loss < best_valid_loss:
                print('Validation loss decreased ({:.4f} --> {:.4f}). Saving autoencoder ...'.format(best_valid_loss,valid_loss))
                torch.save(state, os.path.join(opt.model_path, 'autoencoder.pth'))
                filename = 'fake_%04d.png' %(epoch)
                val_path = os.path.join(opt.val_path, filename)
                output = output.view(output.size(0), 1, 28, 28)
                torchvision.utils.save_image(output.cpu().data, val_path)
                best_valid_loss = valid_loss
                
                
    filepath=os.path.join(opt.save_path, 'autoencoder_losses.png')
    plt.title("Training Curve")
    plt.plot(epoches, train_loss, label="Train")
    plt.plot(epoches, val_loss, label="Validation")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend(loc='best')
    plt.savefig(filepath)

# %%
#train and validate the autoencoder
train_autoencoder()

# %%
#classifier Network
# LeNet Model definition

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 10, kernel_size=5)
        self.conv2 = nn.Conv2d(10, 20, kernel_size=5)
        self.conv2_drop = nn.Dropout2d()
        self.fc1 = nn.Linear(320, 50)
        self.fc2 = nn.Linear(50, 10)

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2_drop(self.conv2(x)), 2))
        x = x.view(-1, 320)
        x = F.relu(self.fc1(x))
        x = F.dropout(x, training=self.training)
        x = self.fc2(x)
        return x

# %%
def train_classifier(**kwargs):
    torch.cuda.empty_cache()
    opt = Config()
    print('loading the model...')  
    model=Net()
    model.to(device)
    autoencoder=Autoencoder().to(device)
    
    optimizer = torch.optim.Adam(model.parameters(), lr = opt.lr,amsgrad=True,weight_decay=5e-4)    
    scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.1)
    criterion = nn.CrossEntropyLoss()

    #loading autoencoder weights
    try:
        state = torch.load(os.path.join(opt.model_path,'autoencoder.pth'))
        autoencoder.load_state_dict(state['state_dict'])
        print("Loaded pre-trained autoencoder with success.")
    except:
        print("Pre-trained autoencoder not found. Train autoencoder first")
        train_autoencoder()
        
        
    
    try:
        state = torch.load(os.path.join(opt.model_path,'classifier.pth'))
        model.load_state_dict(state['state_dict'])
        print("Loaded pre-trained classifier with success.")
        e_counter=state['epoch']
        best_valid_loss = state['valid_loss_min']
        best_valid_acc = state['valid_acc_max']
        print('Previously Trained for {} epoches'.format(e_counter))
        print('Best Validation loss till yet :',best_valid_loss)
        print('Best val Accuracy till yet :',best_valid_acc,'%')
        e_counter+=1
    except FileNotFoundError:
        print("Pre-trained classifier not found. Training from scratch.")
        e_counter=0
        best_valid_loss = float('inf')
        prev_loss=float('inf')
        best_valid_acc = 0.00


    train_loss = []
    train_accuracy = []
    val_loss=[]
    val_accuracy=[]
    epoches=[]
    
    for epoch in range(e_counter,opt.max_epochs):
        model.train()
        print()
        print('==================================================================')
        print('-------------Epoch: {}/{}------------'.format(epoch,opt.max_epochs))
        epoch_loss=0.0
        correct = 0
        total = 0
        train_acc = 0.0
        for idx,batch in enumerate(train_loader):
            image,label=batch
            image,label=image.to(device),label.to(device)
            label=label.squeeze()
            
            optimizer.zero_grad()
            
            image = image.view(image.size(0),-1)
            dec_out = autoencoder(image)
            dec_out = dec_out.view(dec_out.size(0),1,28,28)
            output = model(dec_out)
            
            loss=criterion(output, label)
            loss.backward()
            optimizer.step()            
            epoch_loss+=loss.item()
            
            _,predicted = torch.max(output.data, 1)
            total += label.size(0)
            correct += predicted.eq(label).sum().item()
            train_acc+=100.*correct/total
            
            if idx%200 == 0:
                print('Batch ',idx,'/',len(train_loader),'||Loss: %.5f ||Acc: %.3f%% '%((epoch_loss/(idx+1)),(train_acc/(idx+1))))
        
        
                
        mean_loss = epoch_loss / len(train_loader)
        train_loss.append(mean_loss)

        mean_acc=train_acc/len(train_loader)
        train_accuracy.append(mean_acc)

        print('Train Loss: %.4f || Train Acc: %.3f%%'%(mean_loss,mean_acc)) 
        
        with open('./checkpoint/classifier_train_logs.txt', 'a') as file:
            file.write('epoch: ' + str(epoch) + ',loss: ' + str(mean_loss)+ ',acc: ' + str(mean_acc) +'\n')
            
        print()    
        print('...........................validation....................................')
          
        model.eval()
        eval_loss = 0.0
        val_acc = 0.0
        v_correct = 0
        v_total = 0
        with torch.no_grad():
            for i, (image,label) in enumerate(val_loader):
                image, label = image.to(device),label.to(device)
                label=label.squeeze()
                
                image = image.view(image.size(0),-1)
                dec_out = autoencoder(image)
                dec_out = dec_out.view(dec_out.size(0),1,28,28)
                output = model(dec_out)
                
                
                loss=criterion(output, label)                
                eval_loss += loss.item()
                
                _, predicted = torch.max(output.data, 1)
                v_total += label.size(0)
                v_correct += predicted.eq(label).sum().item()
                val_acc+=100.*v_correct/v_total
                
                if i%100 == 0:
                    print('Batch ',i,'/',len(val_loader), '||Loss: %.5f ||Acc: %.3f%%'%((eval_loss/(i+1)),(val_acc/(i+1))))
                
        valid_loss = eval_loss/len(val_loader)
        valid_acc=val_acc/len(val_loader)
        print('val Loss: %.4f || val Acc: %.3f%%'%(valid_loss,valid_acc))
        val_loss.append(valid_loss)
        val_accuracy.append(valid_acc)
        epoches.append(epoch)

        
        state = {
                'epoch': epoch,
                'valid_loss_min': valid_loss,
                'valid_acc_max': valid_acc,
                'state_dict': model.state_dict(),
                'optimizer': optimizer.state_dict()
                }
        
        if epoch % opt.save_every == 0 or epoch == opt.max_epochs - 1:
            if valid_acc > best_valid_acc:
                print('Validation acc increased ({:.5f} --> {:.5f}). Saving model ...'.format(best_valid_acc,valid_acc))
                torch.save(state, os.path.join(opt.model_path, 'classifier.pth'))  
                
                with open('./checkpoint/classifer_val_logs.txt', 'a') as file:
                    file.write('epoch: ' + str(epoch) + ',loss: ' + str(valid_loss) + ',acc: ' + str(valid_acc) + '\n')
                
                best_valid_acc = valid_acc
                
    filepath=os.path.join(opt.save_path, 'classifier_losses.png')
    plt.title("Training Curve")
    plt.plot(epoches, train_loss, label="Train")
    plt.plot(epoches, val_loss, label="Validation")
    plt.xlabel("Epochs")
    plt.ylabel("Loss")
    plt.legend(loc='best')
    plt.savefig(filepath)
    
    
#     filepath=os.path.join(opt.save_path, 'classifier_accuracy.png')
#     plt.title("Training Curve")
#     plt.plot(epoches, train_acc, label="Train")
#     plt.plot(epoches, val_acc, label="Validation")
#     plt.xlabel("Epochs")
#     plt.ylabel("ACC")
#     plt.legend(loc='best')
#     plt.savefig(filepath)

# %%
train_classifier()
# Out:
# loading the model...
# Loaded pre-trained autoencoder with success.
# Pre-trained classifier not found. Training from scratch.
#
# ==================================================================
# -------------Epoch: 0/100------------
# Batch  0 / 750 ||Loss: 2.31255 ||Acc: 6.250%
# Batch  200 / 750 ||Loss: 1.03651 ||Acc: 47.735%
# Batch  400 / 750 ||Loss: 0.75962 ||Acc: 59.661%
# Batch  600 / 750 ||Loss: 0.63766 ||Acc: 65.729%
# Train Loss: 0.5831 || Train Acc: 68.736%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.04635 ||Acc: 100.000%
# Batch  100 / 188 ||Loss: 0.15290 ||Acc: 95.654%
# val Loss: 0.1558 || val Acc: 95.532%
# Validation acc increased (0.00000 --> 95.53189). Saving model ...
#
# ==================================================================
# -------------Epoch: 1/100------------
# Batch  0 / 750 ||Loss: 0.27904 ||Acc: 92.188%
# Batch  200 / 750 ||Loss: 0.33624 ||Acc: 89.757%
# Batch  400 / 750 ||Loss: 0.31629 ||Acc: 90.081%
# Batch  600 / 750 ||Loss: 0.30779 ||Acc: 90.358%
# Train Loss: 0.3004 || Train Acc: 90.518%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.09776 ||Acc: 95.312%
# Batch  100 / 188 ||Loss: 0.11872 ||Acc: 96.540%
# val Loss: 0.1180 || val Acc: 96.594%
# Validation acc increased (95.53189 --> 96.59396). Saving model ...
#
# ==================================================================
# -------------Epoch: 2/100------------
# Batch  0 / 750 ||Loss: 0.26446 ||Acc: 87.500%
# Batch  200 / 750 ||Loss: 0.26849 ||Acc: 91.989%
# Batch  400 / 750 ||Loss: 0.25995 ||Acc: 92.101%
# Batch  600 / 750 ||Loss: 0.25251 ||Acc: 92.221%
# Train Loss: 0.2493 || Train Acc: 92.297%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.07695 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.10869 ||Acc: 96.996%
# val Loss: 0.1070 || val Acc: 96.900%
# Validation acc increased (96.59396 --> 96.89993). Saving model ...
#
# ==================================================================
# -------------Epoch: 3/100------------
# Batch  0 / 750 ||Loss: 0.16163 ||Acc: 95.312%
# Batch  200 / 750 ||Loss: 0.23892 ||Acc: 93.171%
# Batch  400 / 750 ||Loss: 0.22932 ||Acc: 93.187%
# Batch  600 / 750 ||Loss: 0.22833 ||Acc: 93.179%
# Train Loss: 0.2297 || Train Acc: 93.185%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.11423 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.09376 ||Acc: 97.479%
# val Loss: 0.0956 || val Acc: 97.343%
# Validation acc increased (96.89993 --> 97.34305). Saving model ...
#
# ==================================================================
# -------------Epoch: 4/100------------
# Batch  0 / 750 ||Loss: 0.20324 ||Acc: 95.312%
# Batch  200 / 750 ||Loss: 0.21408 ||Acc: 93.804%
# Batch  400 / 750 ||Loss: 0.21176 ||Acc: 93.874%
# Batch  600 / 750 ||Loss: 0.20991 ||Acc: 93.894%
# Train Loss: 0.2094 || Train Acc: 93.899%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.07177 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.10054 ||Acc: 97.082%
# val Loss: 0.0961 || val Acc: 97.050%
#
# ==================================================================
# -------------Epoch: 5/100------------
# Batch  0 / 750 ||Loss: 0.10576 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.19906 ||Acc: 93.612%
# Batch  400 / 750 ||Loss: 0.19833 ||Acc: 93.784%
# Batch  600 / 750 ||Loss: 0.20401 ||Acc: 93.861%
# Train Loss: 0.2029 || Train Acc: 93.894%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.01511 ||Acc: 100.000%
# Batch  100 / 188 ||Loss: 0.08009 ||Acc: 97.891%
# val Loss: 0.0856 || val Acc: 97.725%
# Validation acc increased (97.34305 --> 97.72475). Saving model ...
#
# ==================================================================
# -------------Epoch: 6/100------------
# Batch  0 / 750 ||Loss: 0.14093 ||Acc: 95.312%
# Batch  200 / 750 ||Loss: 0.21111 ||Acc: 94.212%
# Batch  400 / 750 ||Loss: 0.19682 ||Acc: 94.268%
# Batch  600 / 750 ||Loss: 0.19461 ||Acc: 94.297%
# Train Loss: 0.1920 || Train Acc: 94.324%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.07940 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.09769 ||Acc: 97.234%
# val Loss: 0.0917 || val Acc: 97.223%
#
# ==================================================================
# -------------Epoch: 7/100------------
# Batch  0 / 750 ||Loss: 0.14963 ||Acc: 93.750%
# Batch  200 / 750 ||Loss: 0.19070 ||Acc: 94.139%
# Batch  400 / 750 ||Loss: 0.18820 ||Acc: 94.357%
# Batch  600 / 750 ||Loss: 0.18677 ||Acc: 94.429%
# Train Loss: 0.1848 || Train Acc: 94.467%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.04219 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.07955 ||Acc: 97.706%
# val Loss: 0.0834 || val Acc: 97.573%
#
# ==================================================================
# -------------Epoch: 8/100------------
# Batch  0 / 750 ||Loss: 0.13398 ||Acc: 95.312%
# Batch  200 / 750 ||Loss: 0.18363 ||Acc: 94.886%
# Batch  400 / 750 ||Loss: 0.18015 ||Acc: 94.892%
# Batch  600 / 750 ||Loss: 0.17778 ||Acc: 94.893%
# Train Loss: 0.1778 || Train Acc: 94.897%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.07797 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.08104 ||Acc: 97.369%
# val Loss: 0.0785 || val Acc: 97.457%
#
# ==================================================================
# -------------Epoch: 9/100------------
# Batch  0 / 750 ||Loss: 0.08163 ||Acc: 98.438%
# Batch  200 / 750 ||Loss: 0.16397 ||Acc: 95.326%
# Batch  400 / 750 ||Loss: 0.16707 ||Acc: 95.209%
# Batch  600 / 750 ||Loss: 0.16928 ||Acc: 95.139%
# Train Loss: 0.1708 || Train Acc: 95.113%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.01965 ||Acc: 100.000%
# Batch  100 / 188 ||Loss: 0.07854 ||Acc: 97.431%
# val Loss: 0.0805 || val Acc: 97.448%
#
# ==================================================================
# -------------Epoch: 10/100------------
# Batch  0 / 750 ||Loss: 0.17928 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.16922 ||Acc: 94.994%
# Batch  400 / 750 ||Loss: 0.16845 ||Acc: 95.000%
# Batch  600 / 750 ||Loss: 0.16473 ||Acc: 95.060%
# Train Loss: 0.1642 || Train Acc: 95.089%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.06467 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.07330 ||Acc: 97.855%
# val Loss: 0.0770 || val Acc: 97.831%
# Validation acc increased (97.72475 --> 97.83111). Saving model ...
#
# ==================================================================
# -------------Epoch: 11/100------------
# Batch  0 / 750 ||Loss: 0.10265 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.15494 ||Acc: 95.265%
# Batch  400 / 750 ||Loss: 0.16193 ||Acc: 95.318%
# Batch  600 / 750 ||Loss: 0.16249 ||Acc: 95.296%
# Train Loss: 0.1622 || Train Acc: 95.290%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.01999 ||Acc: 100.000%
# Batch  100 / 188 ||Loss: 0.07386 ||Acc: 97.764%
# val Loss: 0.0765 || val Acc: 97.778%
#
# ==================================================================
# -------------Epoch: 12/100------------
# Batch  0 / 750 ||Loss: 0.16670 ||Acc: 93.750%
# Batch  200 / 750 ||Loss: 0.15751 ||Acc: 95.065%
# Batch  400 / 750 ||Loss: 0.16148 ||Acc: 95.174%
# Batch  600 / 750 ||Loss: 0.15787 ||Acc: 95.250%
# Train Loss: 0.1569 || Train Acc: 95.289%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.05379 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.07713 ||Acc: 97.377%
# val Loss: 0.0782 || val Acc: 97.494%
#
# ==================================================================
# -------------Epoch: 13/100------------
# Batch  0 / 750 ||Loss: 0.11564 ||Acc: 95.312%
# Batch  200 / 750 ||Loss: 0.15560 ||Acc: 95.446%
# Batch  400 / 750 ||Loss: 0.16275 ||Acc: 95.369%
# Batch  600 / 750 ||Loss: 0.16028 ||Acc: 95.308%
# Train Loss: 0.1611 || Train Acc: 95.301%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.05362 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.07003 ||Acc: 98.066%
# val Loss: 0.0726 || val Acc: 97.955%
# Validation acc increased (97.83111 --> 97.95486). Saving model ...
#
# ==================================================================
# -------------Epoch: 14/100------------
# Batch  0 / 750 ||Loss: 0.16662 ||Acc: 93.750%
# Batch  200 / 750 ||Loss: 0.15405 ||Acc: 95.563%
# Batch  400 / 750 ||Loss: 0.15259 ||Acc: 95.514%
# Batch  600 / 750 ||Loss: 0.15537 ||Acc: 95.485%
# Train Loss: 0.1575 || Train Acc: 95.463%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.05687 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.08906 ||Acc: 97.326%
# val Loss: 0.0750 || val Acc: 97.534%
#
# ==================================================================
# -------------Epoch: 15/100------------
# Batch  0 / 750 ||Loss: 0.06389 ||Acc: 98.438%
# Batch  200 / 750 ||Loss: 0.15697 ||Acc: 95.361%
# Batch  400 / 750 ||Loss: 0.15439 ||Acc: 95.313%
# Batch  600 / 750 ||Loss: 0.15263 ||Acc: 95.329%
# Train Loss: 0.1515 || Train Acc: 95.359%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.06943 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.07609 ||Acc: 97.628%
# val Loss: 0.0732 || val Acc: 97.720%
#
# ==================================================================
# -------------Epoch: 16/100------------
# Batch  0 / 750 ||Loss: 0.33666 ||Acc: 92.188%
# Batch  200 / 750 ||Loss: 0.14198 ||Acc: 95.766%
# Batch  400 / 750 ||Loss: 0.14511 ||Acc: 95.736%
# Batch  600 / 750 ||Loss: 0.14968 ||Acc: 95.706%
# Train Loss: 0.1514 || Train Acc: 95.685%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.09016 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.07423 ||Acc: 97.647%
# val Loss: 0.0717 || val Acc: 97.747%
#
# ==================================================================
# -------------Epoch: 17/100------------
# Batch  0 / 750 ||Loss: 0.04656 ||Acc: 100.000%
# Batch  200 / 750 ||Loss: 0.14525 ||Acc: 95.677%
# Batch  400 / 750 ||Loss: 0.14627 ||Acc: 95.729%
# Batch  600 / 750 ||Loss: 0.14688 ||Acc: 95.698%
# Train Loss: 0.1472 || Train Acc: 95.690%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.10287 ||Acc: 95.312%
# Batch  100 / 188 ||Loss: 0.06969 ||Acc: 97.898%
# val Loss: 0.0696 || val Acc: 97.928%
#
# ==================================================================
# -------------Epoch: 18/100------------
# Batch  0 / 750 ||Loss: 0.21058 ||Acc: 95.312%
# Batch  200 / 750 ||Loss: 0.14374 ||Acc: 96.276%
# Batch  400 / 750 ||Loss: 0.14718 ||Acc: 96.051%
# Batch  600 / 750 ||Loss: 0.14905 ||Acc: 95.950%
# Train Loss: 0.1482 || Train Acc: 95.899%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.02787 ||Acc: 100.000%
# Batch  100 / 188 ||Loss: 0.06988 ||Acc: 97.869%
# val Loss: 0.0673 || val Acc: 97.856%
#
# ==================================================================
# -------------Epoch: 19/100------------
# Batch  0 / 750 ||Loss: 0.07235 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.14249 ||Acc: 95.580%
# Batch  400 / 750 ||Loss: 0.14754 ||Acc: 95.648%
# Batch  600 / 750 ||Loss: 0.14815 ||Acc: 95.666%
# Train Loss: 0.1479 || Train Acc: 95.671%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.07317 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.07209 ||Acc: 97.914%
# val Loss: 0.0722 || val Acc: 97.881%
#
# ==================================================================
# -------------Epoch: 20/100------------
# Batch  0 / 750 ||Loss: 0.08745 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.14389 ||Acc: 96.058%
# Batch  400 / 750 ||Loss: 0.15041 ||Acc: 95.942%
# Batch  600 / 750 ||Loss: 0.14338 ||Acc: 95.881%
# Train Loss: 0.1432 || Train Acc: 95.876%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.03268 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06566 ||Acc: 97.929%
# val Loss: 0.0683 || val Acc: 97.920%
#
# ==================================================================
# -------------Epoch: 21/100------------
# Batch  0 / 750 ||Loss: 0.02835 ||Acc: 100.000%
# Batch  200 / 750 ||Loss: 0.14427 ||Acc: 96.015%
# Batch  400 / 750 ||Loss: 0.14127 ||Acc: 95.969%
# Batch  600 / 750 ||Loss: 0.14644 ||Acc: 95.945%
# Train Loss: 0.1448 || Train Acc: 95.925%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.02392 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.07188 ||Acc: 97.524%
# val Loss: 0.0715 || val Acc: 97.633%
#
# ==================================================================
# -------------Epoch: 22/100------------
# Batch  0 / 750 ||Loss: 0.10295 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.14529 ||Acc: 95.769%
# Batch  400 / 750 ||Loss: 0.14241 ||Acc: 95.882%
# Batch  600 / 750 ||Loss: 0.14212 ||Acc: 95.918%
# Train Loss: 0.1407 || Train Acc: 95.925%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.01945 ||Acc: 100.000%
# Batch  100 / 188 ||Loss: 0.07020 ||Acc: 97.996%
# val Loss: 0.0696 || val Acc: 97.940%
#
# ==================================================================
# -------------Epoch: 23/100------------
# Batch  0 / 750 ||Loss: 0.10426 ||Acc: 95.312%
# Batch  200 / 750 ||Loss: 0.14007 ||Acc: 95.769%
# Batch  400 / 750 ||Loss: 0.14092 ||Acc: 95.842%
# Batch  600 / 750 ||Loss: 0.14295 ||Acc: 95.854%
# Train Loss: 0.1415 || Train Acc: 95.860%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.07817 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06540 ||Acc: 98.293%
# val Loss: 0.0725 || val Acc: 98.135%
# Validation acc increased (97.95486 --> 98.13534). Saving model ...
#
# ==================================================================
# -------------Epoch: 24/100------------
# Batch  0 / 750 ||Loss: 0.20584 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.12783 ||Acc: 96.146%
# Batch  400 / 750 ||Loss: 0.13081 ||Acc: 96.141%
# Batch  600 / 750 ||Loss: 0.13460 ||Acc: 96.105%
# Train Loss: 0.1373 || Train Acc: 96.082%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.10463 ||Acc: 95.312%
# Batch  100 / 188 ||Loss: 0.07745 ||Acc: 97.638%
# val Loss: 0.0747 || val Acc: 97.686%
#
# ==================================================================
# -------------Epoch: 25/100------------
# Batch  0 / 750 ||Loss: 0.01421 ||Acc: 100.000%
# Batch  200 / 750 ||Loss: 0.13587 ||Acc: 96.160%
# Batch  400 / 750 ||Loss: 0.13976 ||Acc: 96.124%
# Batch  600 / 750 ||Loss: 0.13658 ||Acc: 96.080%
# Train Loss: 0.1357 || Train Acc: 96.076%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.01152 ||Acc: 100.000%
# Batch  100 / 188 ||Loss: 0.07018 ||Acc: 98.339%
# val Loss: 0.0712 || val Acc: 98.154%
# Validation acc increased (98.13534 --> 98.15352). Saving model ...
#
# ==================================================================
# -------------Epoch: 26/100------------
# Batch  0 / 750 ||Loss: 0.15084 ||Acc: 93.750%
# Batch  200 / 750 ||Loss: 0.13289 ||Acc: 96.159%
# Batch  400 / 750 ||Loss: 0.13238 ||Acc: 96.124%
# Batch  600 / 750 ||Loss: 0.13048 ||Acc: 96.102%
# Train Loss: 0.1336 || Train Acc: 96.102%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.22462 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.06799 ||Acc: 97.853%
# val Loss: 0.0709 || val Acc: 97.816%
#
# ==================================================================
# -------------Epoch: 27/100------------
# Batch  0 / 750 ||Loss: 0.10380 ||Acc: 95.312%
# Batch  200 / 750 ||Loss: 0.12902 ||Acc: 96.109%
# Batch  400 / 750 ||Loss: 0.13393 ||Acc: 96.061%
# Batch  600 / 750 ||Loss: 0.13650 ||Acc: 96.020%
# Train Loss: 0.1384 || Train Acc: 96.005%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.08282 ||Acc: 95.312%
# Batch  100 / 188 ||Loss: 0.06822 ||Acc: 97.645%
# val Loss: 0.0675 || val Acc: 97.750%
#
# ==================================================================
# -------------Epoch: 28/100------------
# Batch  0 / 750 ||Loss: 0.13559 ||Acc: 98.438%
# Batch  200 / 750 ||Loss: 0.12760 ||Acc: 96.282%
# Batch  400 / 750 ||Loss: 0.13492 ||Acc: 96.160%
# Batch  600 / 750 ||Loss: 0.13367 ||Acc: 96.119%
# Train Loss: 0.1384 || Train Acc: 96.090%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.07935 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.06387 ||Acc: 98.165%
# val Loss: 0.0661 || val Acc: 98.069%
#
# ==================================================================
# -------------Epoch: 29/100------------
# Batch  0 / 750 ||Loss: 0.09585 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.13879 ||Acc: 95.662%
# Batch  400 / 750 ||Loss: 0.13824 ||Acc: 95.810%
# Batch  600 / 750 ||Loss: 0.13718 ||Acc: 95.871%
# Train Loss: 0.1358 || Train Acc: 95.917%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.16117 ||Acc: 95.312%
# Batch  100 / 188 ||Loss: 0.06977 ||Acc: 97.751%
# val Loss: 0.0708 || val Acc: 97.865%
#
# ==================================================================
# -------------Epoch: 30/100------------
# Batch  0 / 750 ||Loss: 0.13289 ||Acc: 95.312%
# Batch  200 / 750 ||Loss: 0.12222 ||Acc: 95.989%
# Batch  400 / 750 ||Loss: 0.13021 ||Acc: 96.094%
# Batch  600 / 750 ||Loss: 0.13169 ||Acc: 96.108%
# Train Loss: 0.1329 || Train Acc: 96.111%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.08938 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.06405 ||Acc: 98.031%
# val Loss: 0.0688 || val Acc: 98.005%
#
# ==================================================================
# -------------Epoch: 31/100------------
# Batch  0 / 750 ||Loss: 0.24209 ||Acc: 95.312%
# Batch  200 / 750 ||Loss: 0.13682 ||Acc: 95.719%
# Batch  400 / 750 ||Loss: 0.13827 ||Acc: 95.818%
# Batch  600 / 750 ||Loss: 0.13489 ||Acc: 95.845%
# Train Loss: 0.1335 || Train Acc: 95.872%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.00374 ||Acc: 100.000%
# Batch  100 / 188 ||Loss: 0.06180 ||Acc: 98.362%
# val Loss: 0.0707 || val Acc: 98.197%
# Validation acc increased (98.15352 --> 98.19710). Saving model ...
#
# ==================================================================
# -------------Epoch: 32/100------------
# Batch  0 / 750 ||Loss: 0.03977 ||Acc: 100.000%
# Batch  200 / 750 ||Loss: 0.12819 ||Acc: 96.501%
# Batch  400 / 750 ||Loss: 0.13167 ||Acc: 96.363%
# Batch  600 / 750 ||Loss: 0.13272 ||Acc: 96.267%
# Train Loss: 0.1320 || Train Acc: 96.244%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.04808 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.07084 ||Acc: 98.109%
# val Loss: 0.0711 || val Acc: 98.061%
#
# ==================================================================
# -------------Epoch: 33/100------------
# Batch  0 / 750 ||Loss: 0.06155 ||Acc: 98.438%
# Batch  200 / 750 ||Loss: 0.13846 ||Acc: 96.401%
# Batch  400 / 750 ||Loss: 0.13376 ||Acc: 96.285%
# Batch  600 / 750 ||Loss: 0.13286 ||Acc: 96.220%
# Train Loss: 0.1313 || Train Acc: 96.193%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.04295 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06269 ||Acc: 98.176%
# val Loss: 0.0664 || val Acc: 98.125%
#
# ==================================================================
# -------------Epoch: 34/100------------
# Batch  0 / 750 ||Loss: 0.11061 ||Acc: 95.312%
# Batch  200 / 750 ||Loss: 0.13870 ||Acc: 96.100%
# Batch  400 / 750 ||Loss: 0.13567 ||Acc: 96.114%
# Batch  600 / 750 ||Loss: 0.13317 ||Acc: 96.136%
# Train Loss: 0.1334 || Train Acc: 96.152%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.00274 ||Acc: 100.000%
# Batch  100 / 188 ||Loss: 0.06386 ||Acc: 98.089%
# val Loss: 0.0656 || val Acc: 98.058%
#
# ==================================================================
# -------------Epoch: 35/100------------
# Batch  0 / 750 ||Loss: 0.12287 ||Acc: 95.312%
# Batch  200 / 750 ||Loss: 0.12577 ||Acc: 96.362%
# Batch  400 / 750 ||Loss: 0.12761 ||Acc: 96.265%
# Batch  600 / 750 ||Loss: 0.13117 ||Acc: 96.204%
# Train Loss: 0.1302 || Train Acc: 96.178%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.02216 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06596 ||Acc: 98.055%
# val Loss: 0.0670 || val Acc: 98.045%
#
# ==================================================================
# -------------Epoch: 36/100------------
# Batch  0 / 750 ||Loss: 0.04535 ||Acc: 100.000%
# Batch  200 / 750 ||Loss: 0.12413 ||Acc: 96.056%
# Batch  400 / 750 ||Loss: 0.12935 ||Acc: 96.092%
# Batch  600 / 750 ||Loss: 0.13053 ||Acc: 96.076%
# Train Loss: 0.1299 || Train Acc: 96.082%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.11052 ||Acc: 95.312%
# Batch  100 / 188 ||Loss: 0.07327 ||Acc: 97.908%
# val Loss: 0.0665 || val Acc: 97.909%
#
# ==================================================================
# -------------Epoch: 37/100------------
# Batch  0 / 750 ||Loss: 0.13325 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.12910 ||Acc: 96.133%
# Batch  400 / 750 ||Loss: 0.12769 ||Acc: 96.212%
# Batch  600 / 750 ||Loss: 0.12803 ||Acc: 96.226%
# Train Loss: 0.1275 || Train Acc: 96.237%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.03151 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06256 ||Acc: 98.035%
# val Loss: 0.0655 || val Acc: 98.011%
#
# ==================================================================
# -------------Epoch: 38/100------------
# Batch  0 / 750 ||Loss: 0.12886 ||Acc: 95.312%
# Batch  200 / 750 ||Loss: 0.12913 ||Acc: 96.212%
# Batch  400 / 750 ||Loss: 0.12935 ||Acc: 96.242%
# Batch  600 / 750 ||Loss: 0.12883 ||Acc: 96.245%
# Train Loss: 0.1297 || Train Acc: 96.238%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.11713 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.07058 ||Acc: 97.886%
# val Loss: 0.0667 || val Acc: 97.881%
#
# ==================================================================
# -------------Epoch: 39/100------------
# Batch  0 / 750 ||Loss: 0.14043 ||Acc: 93.750%
# Batch  200 / 750 ||Loss: 0.11958 ||Acc: 96.489%
# Batch  400 / 750 ||Loss: 0.12453 ||Acc: 96.438%
# Batch  600 / 750 ||Loss: 0.12889 ||Acc: 96.373%
# Train Loss: 0.1298 || Train Acc: 96.333%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.08910 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.06573 ||Acc: 97.964%
# val Loss: 0.0693 || val Acc: 97.968%
#
# ==================================================================
# -------------Epoch: 40/100------------
# Batch  0 / 750 ||Loss: 0.04188 ||Acc: 98.438%
# Batch  200 / 750 ||Loss: 0.11627 ||Acc: 96.348%
# Batch  400 / 750 ||Loss: 0.12311 ||Acc: 96.360%
# Batch  600 / 750 ||Loss: 0.12369 ||Acc: 96.358%
# Train Loss: 0.1264 || Train Acc: 96.351%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.01881 ||Acc: 100.000%
# Batch  100 / 188 ||Loss: 0.07051 ||Acc: 98.087%
# val Loss: 0.0708 || val Acc: 98.057%
#
# ==================================================================
# -------------Epoch: 41/100------------
# Batch  0 / 750 ||Loss: 0.16129 ||Acc: 93.750%
# Batch  200 / 750 ||Loss: 0.12033 ||Acc: 96.225%
# Batch  400 / 750 ||Loss: 0.12394 ||Acc: 96.330%
# Batch  600 / 750 ||Loss: 0.12782 ||Acc: 96.346%
# Train Loss: 0.1303 || Train Acc: 96.329%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.10830 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.06554 ||Acc: 97.990%
# val Loss: 0.0651 || val Acc: 98.016%
#
# ==================================================================
# -------------Epoch: 42/100------------
# Batch  0 / 750 ||Loss: 0.08347 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.12537 ||Acc: 96.351%
# Batch  400 / 750 ||Loss: 0.12565 ||Acc: 96.282%
# Batch  600 / 750 ||Loss: 0.12876 ||Acc: 96.264%
# Train Loss: 0.1310 || Train Acc: 96.245%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.06099 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.06645 ||Acc: 97.984%
# val Loss: 0.0695 || val Acc: 97.990%
#
# ==================================================================
# -------------Epoch: 43/100------------
# Batch  0 / 750 ||Loss: 0.09215 ||Acc: 95.312%
# Batch  200 / 750 ||Loss: 0.12721 ||Acc: 96.460%
# Batch  400 / 750 ||Loss: 0.12677 ||Acc: 96.373%
# Batch  600 / 750 ||Loss: 0.12727 ||Acc: 96.317%
# Train Loss: 0.1276 || Train Acc: 96.291%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.01208 ||Acc: 100.000%
# Batch  100 / 188 ||Loss: 0.06916 ||Acc: 98.093%
# val Loss: 0.0674 || val Acc: 98.093%
#
# ==================================================================
# -------------Epoch: 44/100------------
# Batch  0 / 750 ||Loss: 0.12780 ||Acc: 93.750%
# Batch  200 / 750 ||Loss: 0.12034 ||Acc: 96.196%
# Batch  400 / 750 ||Loss: 0.12505 ||Acc: 96.317%
# Batch  600 / 750 ||Loss: 0.12601 ||Acc: 96.322%
# Train Loss: 0.1265 || Train Acc: 96.319%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.03478 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06144 ||Acc: 97.827%
# val Loss: 0.0676 || val Acc: 97.882%
#
# ==================================================================
# -------------Epoch: 45/100------------
# Batch  0 / 750 ||Loss: 0.05935 ||Acc: 98.438%
# Batch  200 / 750 ||Loss: 0.12105 ||Acc: 96.364%
# Batch  400 / 750 ||Loss: 0.12341 ||Acc: 96.314%
# Batch  600 / 750 ||Loss: 0.12474 ||Acc: 96.300%
# Train Loss: 0.1269 || Train Acc: 96.292%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.00797 ||Acc: 100.000%
# Batch  100 / 188 ||Loss: 0.06870 ||Acc: 98.155%
# val Loss: 0.0684 || val Acc: 98.073%
#
# ==================================================================
# -------------Epoch: 46/100------------
# Batch  0 / 750 ||Loss: 0.10411 ||Acc: 98.438%
# Batch  200 / 750 ||Loss: 0.13187 ||Acc: 96.030%
# Batch  400 / 750 ||Loss: 0.12741 ||Acc: 96.091%
# Batch  600 / 750 ||Loss: 0.12905 ||Acc: 96.110%
# Train Loss: 0.1276 || Train Acc: 96.116%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.19295 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.07151 ||Acc: 98.268%
# val Loss: 0.0651 || val Acc: 98.186%
#
# ==================================================================
# -------------Epoch: 47/100------------
# Batch  0 / 750 ||Loss: 0.06177 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.12370 ||Acc: 96.416%
# Batch  400 / 750 ||Loss: 0.12519 ||Acc: 96.318%
# Batch  600 / 750 ||Loss: 0.12121 ||Acc: 96.313%
# Train Loss: 0.1266 || Train Acc: 96.317%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.13096 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.07109 ||Acc: 97.363%
# val Loss: 0.0698 || val Acc: 97.476%
#
# ==================================================================
# -------------Epoch: 48/100------------
# Batch  0 / 750 ||Loss: 0.06010 ||Acc: 98.438%
# Batch  200 / 750 ||Loss: 0.13118 ||Acc: 96.210%
# Batch  400 / 750 ||Loss: 0.12749 ||Acc: 96.222%
# Batch  600 / 750 ||Loss: 0.12746 ||Acc: 96.240%
# Train Loss: 0.1262 || Train Acc: 96.243%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.06565 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06449 ||Acc: 97.974%
# val Loss: 0.0666 || val Acc: 98.028%
#
# ==================================================================
# -------------Epoch: 49/100------------
# Batch  0 / 750 ||Loss: 0.16646 ||Acc: 95.312%
# Batch  200 / 750 ||Loss: 0.12407 ||Acc: 96.474%
# Batch  400 / 750 ||Loss: 0.12097 ||Acc: 96.560%
# Batch  600 / 750 ||Loss: 0.12253 ||Acc: 96.576%
# Train Loss: 0.1211 || Train Acc: 96.563%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.12293 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.07108 ||Acc: 98.136%
# val Loss: 0.0713 || val Acc: 97.997%
#
# ==================================================================
# -------------Epoch: 50/100------------
# Batch  0 / 750 ||Loss: 0.06279 ||Acc: 98.438%
# Batch  200 / 750 ||Loss: 0.13085 ||Acc: 96.166%
# Batch  400 / 750 ||Loss: 0.12359 ||Acc: 96.239%
# Batch  600 / 750 ||Loss: 0.12295 ||Acc: 96.286%
# Train Loss: 0.1272 || Train Acc: 96.297%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.09668 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06607 ||Acc: 97.869%
# val Loss: 0.0667 || val Acc: 97.885%
#
# ==================================================================
# -------------Epoch: 51/100------------
# Batch  0 / 750 ||Loss: 0.09338 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.12280 ||Acc: 96.642%
# Batch  400 / 750 ||Loss: 0.12319 ||Acc: 96.508%
# Batch  600 / 750 ||Loss: 0.12473 ||Acc: 96.470%
# Train Loss: 0.1241 || Train Acc: 96.454%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.01684 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06167 ||Acc: 97.757%
# val Loss: 0.0641 || val Acc: 97.884%
#
# ==================================================================
# -------------Epoch: 52/100------------
# Batch  0 / 750 ||Loss: 0.04854 ||Acc: 100.000%
# Batch  200 / 750 ||Loss: 0.12047 ||Acc: 96.408%
# Batch  400 / 750 ||Loss: 0.12029 ||Acc: 96.468%
# Batch  600 / 750 ||Loss: 0.12378 ||Acc: 96.445%
# Train Loss: 0.1238 || Train Acc: 96.429%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.12869 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.06653 ||Acc: 98.179%
# val Loss: 0.0644 || val Acc: 98.078%
#
# ==================================================================
# -------------Epoch: 53/100------------
# Batch  0 / 750 ||Loss: 0.05875 ||Acc: 98.438%
# Batch  200 / 750 ||Loss: 0.12917 ||Acc: 96.460%
# Batch  400 / 750 ||Loss: 0.12493 ||Acc: 96.383%
# Batch  600 / 750 ||Loss: 0.12429 ||Acc: 96.351%
# Train Loss: 0.1227 || Train Acc: 96.333%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.08534 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.07139 ||Acc: 97.833%
# val Loss: 0.0692 || val Acc: 97.910%
#
# ==================================================================
# -------------Epoch: 54/100------------
# Batch  0 / 750 ||Loss: 0.03792 ||Acc: 98.438%
# Batch  200 / 750 ||Loss: 0.11958 ||Acc: 96.432%
# Batch  400 / 750 ||Loss: 0.11486 ||Acc: 96.526%
# Batch  600 / 750 ||Loss: 0.11704 ||Acc: 96.548%
# Train Loss: 0.1189 || Train Acc: 96.547%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.09882 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06782 ||Acc: 97.917%
# val Loss: 0.0644 || val Acc: 97.979%
#
# ==================================================================
# -------------Epoch: 55/100------------
# Batch  0 / 750 ||Loss: 0.06372 ||Acc: 98.438%
# Batch  200 / 750 ||Loss: 0.11984 ||Acc: 96.510%
# Batch  400 / 750 ||Loss: 0.12255 ||Acc: 96.520%
# Batch  600 / 750 ||Loss: 0.12224 ||Acc: 96.519%
# Train Loss: 0.1236 || Train Acc: 96.500%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.00927 ||Acc: 100.000%
# Batch  100 / 188 ||Loss: 0.06322 ||Acc: 98.401%
# val Loss: 0.0648 || val Acc: 98.264%
# Validation acc increased (98.19710 --> 98.26424). Saving model ...
#
# ==================================================================
# -------------Epoch: 56/100------------
# Batch  0 / 750 ||Loss: 0.19396 ||Acc: 93.750%
# Batch  200 / 750 ||Loss: 0.11819 ||Acc: 96.623%
# Batch  400 / 750 ||Loss: 0.11729 ||Acc: 96.606%
# Batch  600 / 750 ||Loss: 0.11691 ||Acc: 96.602%
# Train Loss: 0.1186 || Train Acc: 96.581%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.00687 ||Acc: 100.000%
# Batch  100 / 188 ||Loss: 0.06723 ||Acc: 98.088%
# val Loss: 0.0650 || val Acc: 98.084%
#
# ==================================================================
# -------------Epoch: 57/100------------
# Batch  0 / 750 ||Loss: 0.25619 ||Acc: 93.750%
# Batch  200 / 750 ||Loss: 0.12753 ||Acc: 96.284%
# Batch  400 / 750 ||Loss: 0.12686 ||Acc: 96.254%
# Batch  600 / 750 ||Loss: 0.12408 ||Acc: 96.270%
# Train Loss: 0.1243 || Train Acc: 96.281%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.00267 ||Acc: 100.000%
# Batch  100 / 188 ||Loss: 0.05862 ||Acc: 98.138%
# val Loss: 0.0627 || val Acc: 98.138%
#
# ==================================================================
# -------------Epoch: 58/100------------
# Batch  0 / 750 ||Loss: 0.03388 ||Acc: 100.000%
# Batch  200 / 750 ||Loss: 0.12353 ||Acc: 96.636%
# Batch  400 / 750 ||Loss: 0.12534 ||Acc: 96.533%
# Batch  600 / 750 ||Loss: 0.12090 ||Acc: 96.483%
# Train Loss: 0.1190 || Train Acc: 96.464%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.00728 ||Acc: 100.000%
# Batch  100 / 188 ||Loss: 0.05457 ||Acc: 98.367%
# val Loss: 0.0656 || val Acc: 98.272%
# Validation acc increased (98.26424 --> 98.27241). Saving model ...
#
# ==================================================================
# -------------Epoch: 59/100------------
# Batch  0 / 750 ||Loss: 0.13036 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.11703 ||Acc: 96.678%
# Batch  400 / 750 ||Loss: 0.12015 ||Acc: 96.554%
# Batch  600 / 750 ||Loss: 0.11977 ||Acc: 96.493%
# Train Loss: 0.1199 || Train Acc: 96.466%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.05247 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06598 ||Acc: 98.225%
# val Loss: 0.0660 || val Acc: 98.190%
#
# ==================================================================
# -------------Epoch: 60/100------------
# Batch  0 / 750 ||Loss: 0.18309 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.11970 ||Acc: 96.948%
# Batch  400 / 750 ||Loss: 0.12157 ||Acc: 96.737%
# Batch  600 / 750 ||Loss: 0.12069 ||Acc: 96.673%
# Train Loss: 0.1212 || Train Acc: 96.645%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.11353 ||Acc: 93.750%
# Batch  100 / 188 ||Loss: 0.06632 ||Acc: 97.787%
# val Loss: 0.0631 || val Acc: 97.917%
#
# ==================================================================
# -------------Epoch: 61/100------------
# Batch  0 / 750 ||Loss: 0.01824 ||Acc: 100.000%
# Batch  200 / 750 ||Loss: 0.12602 ||Acc: 96.700%
# Batch  400 / 750 ||Loss: 0.12245 ||Acc: 96.531%
# Batch  600 / 750 ||Loss: 0.12078 ||Acc: 96.499%
# Train Loss: 0.1207 || Train Acc: 96.489%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.02497 ||Acc: 100.000%
# Batch  100 / 188 ||Loss: 0.05921 ||Acc: 98.066%
# val Loss: 0.0629 || val Acc: 98.087%
#
# ==================================================================
# -------------Epoch: 62/100------------
# Batch  0 / 750 ||Loss: 0.10719 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.11989 ||Acc: 96.358%
# Batch  400 / 750 ||Loss: 0.11438 ||Acc: 96.427%
# Batch  600 / 750 ||Loss: 0.11696 ||Acc: 96.480%
# Train Loss: 0.1177 || Train Acc: 96.494%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.03619 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06000 ||Acc: 98.279%
# val Loss: 0.0651 || val Acc: 98.234%
#
# ==================================================================
# -------------Epoch: 63/100------------
# Batch  0 / 750 ||Loss: 0.06319 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.11782 ||Acc: 96.620%
# Batch  400 / 750 ||Loss: 0.11927 ||Acc: 96.546%
# Batch  600 / 750 ||Loss: 0.12192 ||Acc: 96.505%
# Train Loss: 0.1218 || Train Acc: 96.481%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.02884 ||Acc: 100.000%
# Batch  100 / 188 ||Loss: 0.06352 ||Acc: 98.110%
# val Loss: 0.0660 || val Acc: 98.057%
#
# ==================================================================
# -------------Epoch: 64/100------------
# Batch  0 / 750 ||Loss: 0.05442 ||Acc: 100.000%
# Batch  200 / 750 ||Loss: 0.11396 ||Acc: 96.791%
# Batch  400 / 750 ||Loss: 0.11698 ||Acc: 96.704%
# Batch  600 / 750 ||Loss: 0.11654 ||Acc: 96.662%
# Train Loss: 0.1164 || Train Acc: 96.646%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.17039 ||Acc: 95.312%
# Batch  100 / 188 ||Loss: 0.06344 ||Acc: 97.800%
# val Loss: 0.0629 || val Acc: 97.951%
#
# ==================================================================
# -------------Epoch: 65/100------------
# Batch  0 / 750 ||Loss: 0.30624 ||Acc: 98.438%
# Batch  200 / 750 ||Loss: 0.12188 ||Acc: 96.598%
# Batch  400 / 750 ||Loss: 0.11906 ||Acc: 96.564%
# Batch  600 / 750 ||Loss: 0.11703 ||Acc: 96.550%
# Train Loss: 0.1187 || Train Acc: 96.545%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.06554 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.06392 ||Acc: 98.167%
# val Loss: 0.0612 || val Acc: 98.109%
#
# ==================================================================
# -------------Epoch: 66/100------------
# Batch  0 / 750 ||Loss: 0.07921 ||Acc: 98.438%
# Batch  200 / 750 ||Loss: 0.10920 ||Acc: 96.781%
# Batch  400 / 750 ||Loss: 0.11584 ||Acc: 96.801%
# Batch  600 / 750 ||Loss: 0.11633 ||Acc: 96.767%
# Train Loss: 0.1175 || Train Acc: 96.750%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.08969 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.06527 ||Acc: 97.964%
# val Loss: 0.0626 || val Acc: 98.031%
#
# ==================================================================
# -------------Epoch: 67/100------------
# Batch  0 / 750 ||Loss: 0.05842 ||Acc: 98.438%
# Batch  200 / 750 ||Loss: 0.11659 ||Acc: 96.712%
# Batch  400 / 750 ||Loss: 0.11766 ||Acc: 96.639%
# Batch  600 / 750 ||Loss: 0.11875 ||Acc: 96.613%
# Train Loss: 0.1195 || Train Acc: 96.595%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.25521 ||Acc: 93.750%
# Batch  100 / 188 ||Loss: 0.07109 ||Acc: 97.851%
# val Loss: 0.0659 || val Acc: 97.974%
#
# ==================================================================
# -------------Epoch: 68/100------------
# Batch  0 / 750 ||Loss: 0.09444 ||Acc: 95.312%
# Batch  200 / 750 ||Loss: 0.11754 ||Acc: 96.380%
# Batch  400 / 750 ||Loss: 0.11840 ||Acc: 96.317%
# Batch  600 / 750 ||Loss: 0.11734 ||Acc: 96.331%
# Train Loss: 0.1187 || Train Acc: 96.341%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.03035 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06210 ||Acc: 98.250%
# val Loss: 0.0630 || val Acc: 98.207%
#
# ==================================================================
# -------------Epoch: 69/100------------
# Batch  0 / 750 ||Loss: 0.12554 ||Acc: 93.750%
# Batch  200 / 750 ||Loss: 0.11218 ||Acc: 96.280%
# Batch  400 / 750 ||Loss: 0.11901 ||Acc: 96.412%
# Batch  600 / 750 ||Loss: 0.11857 ||Acc: 96.457%
# Train Loss: 0.1192 || Train Acc: 96.484%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.06281 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06345 ||Acc: 98.238%
# val Loss: 0.0621 || val Acc: 98.222%
#
# ==================================================================
# -------------Epoch: 70/100------------
# Batch  0 / 750 ||Loss: 0.08060 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.11251 ||Acc: 96.667%
# Batch  400 / 750 ||Loss: 0.11652 ||Acc: 96.681%
# Batch  600 / 750 ||Loss: 0.11825 ||Acc: 96.676%
# Train Loss: 0.1186 || Train Acc: 96.670%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.01787 ||Acc: 100.000%
# Batch  100 / 188 ||Loss: 0.06442 ||Acc: 97.874%
# val Loss: 0.0608 || val Acc: 97.958%
#
# ==================================================================
# -------------Epoch: 71/100------------
# Batch  0 / 750 ||Loss: 0.14269 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.11375 ||Acc: 96.459%
# Batch  400 / 750 ||Loss: 0.11461 ||Acc: 96.478%
# Batch  600 / 750 ||Loss: 0.11919 ||Acc: 96.507%
# Train Loss: 0.1191 || Train Acc: 96.506%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.03379 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.07203 ||Acc: 98.254%
# val Loss: 0.0675 || val Acc: 98.233%
#
# ==================================================================
# -------------Epoch: 72/100------------
# Batch  0 / 750 ||Loss: 0.11380 ||Acc: 93.750%
# Batch  200 / 750 ||Loss: 0.11661 ||Acc: 96.585%
# Batch  400 / 750 ||Loss: 0.11853 ||Acc: 96.573%
# Batch  600 / 750 ||Loss: 0.11771 ||Acc: 96.575%
# Train Loss: 0.1179 || Train Acc: 96.594%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.16621 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.06443 ||Acc: 98.223%
# val Loss: 0.0637 || val Acc: 98.187%
#
# ==================================================================
# -------------Epoch: 73/100------------
# Batch  0 / 750 ||Loss: 0.03540 ||Acc: 100.000%
# Batch  200 / 750 ||Loss: 0.11484 ||Acc: 96.912%
# Batch  400 / 750 ||Loss: 0.11374 ||Acc: 96.779%
# Batch  600 / 750 ||Loss: 0.11660 ||Acc: 96.740%
# Train Loss: 0.1153 || Train Acc: 96.730%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.02576 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06191 ||Acc: 98.207%
# val Loss: 0.0646 || val Acc: 98.186%
#
# ==================================================================
# -------------Epoch: 74/100------------
# Batch  0 / 750 ||Loss: 0.02365 ||Acc: 100.000%
# Batch  200 / 750 ||Loss: 0.11985 ||Acc: 96.531%
# Batch  400 / 750 ||Loss: 0.11577 ||Acc: 96.467%
# Batch  600 / 750 ||Loss: 0.11367 ||Acc: 96.505%
# Train Loss: 0.1146 || Train Acc: 96.520%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.05376 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06052 ||Acc: 98.311%
# val Loss: 0.0609 || val Acc: 98.294%
# Validation acc increased (98.27241 --> 98.29439). Saving model ...
#
# ==================================================================
# -------------Epoch: 75/100------------
# Batch  0 / 750 ||Loss: 0.13654 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.11005 ||Acc: 96.487%
# Batch  400 / 750 ||Loss: 0.11912 ||Acc: 96.497%
# Batch  600 / 750 ||Loss: 0.11857 ||Acc: 96.466%
# Train Loss: 0.1173 || Train Acc: 96.466%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.02580 ||Acc: 100.000%
# Batch  100 / 188 ||Loss: 0.06246 ||Acc: 98.276%
# val Loss: 0.0645 || val Acc: 98.256%
#
# ==================================================================
# -------------Epoch: 76/100------------
# Batch  0 / 750 ||Loss: 0.12147 ||Acc: 98.438%
# Batch  200 / 750 ||Loss: 0.11542 ||Acc: 96.712%
# Batch  400 / 750 ||Loss: 0.11571 ||Acc: 96.732%
# Batch  600 / 750 ||Loss: 0.11686 ||Acc: 96.698%
# Train Loss: 0.1186 || Train Acc: 96.675%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.05208 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.05974 ||Acc: 98.456%
# val Loss: 0.0629 || val Acc: 98.377%
# Validation acc increased (98.29439 --> 98.37713). Saving model ...
#
# ==================================================================
# -------------Epoch: 77/100------------
# Batch  0 / 750 ||Loss: 0.15570 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.10980 ||Acc: 96.659%
# Batch  400 / 750 ||Loss: 0.11628 ||Acc: 96.629%
# Batch  600 / 750 ||Loss: 0.11596 ||Acc: 96.594%
# Train Loss: 0.1165 || Train Acc: 96.576%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.01038 ||Acc: 100.000%
# Batch  100 / 188 ||Loss: 0.06548 ||Acc: 98.277%
# val Loss: 0.0642 || val Acc: 98.194%
#
# ==================================================================
# -------------Epoch: 78/100------------
# Batch  0 / 750 ||Loss: 0.08913 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.12057 ||Acc: 96.512%
# Batch  400 / 750 ||Loss: 0.11858 ||Acc: 96.487%
# Batch  600 / 750 ||Loss: 0.11685 ||Acc: 96.507%
# Train Loss: 0.1158 || Train Acc: 96.520%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.08151 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06594 ||Acc: 98.055%
# val Loss: 0.0619 || val Acc: 98.090%
#
# ==================================================================
# -------------Epoch: 79/100------------
# Batch  0 / 750 ||Loss: 0.08407 ||Acc: 100.000%
# Batch  200 / 750 ||Loss: 0.11547 ||Acc: 96.891%
# Batch  400 / 750 ||Loss: 0.11348 ||Acc: 96.787%
# Batch  600 / 750 ||Loss: 0.11658 ||Acc: 96.753%
# Train Loss: 0.1146 || Train Acc: 96.736%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.01931 ||Acc: 100.000%
# Batch  100 / 188 ||Loss: 0.06534 ||Acc: 98.517%
# val Loss: 0.0655 || val Acc: 98.364%
#
# ==================================================================
# -------------Epoch: 80/100------------
# Batch  0 / 750 ||Loss: 0.08416 ||Acc: 98.438%
# Batch  200 / 750 ||Loss: 0.11241 ||Acc: 96.624%
# Batch  400 / 750 ||Loss: 0.11292 ||Acc: 96.631%
# Batch  600 / 750 ||Loss: 0.11570 ||Acc: 96.619%
# Train Loss: 0.1173 || Train Acc: 96.608%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.08920 ||Acc: 95.312%
# Batch  100 / 188 ||Loss: 0.06310 ||Acc: 97.993%
# val Loss: 0.0618 || val Acc: 98.046%
#
# ==================================================================
# -------------Epoch: 81/100------------
# Batch  0 / 750 ||Loss: 0.13512 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.11107 ||Acc: 96.833%
# Batch  400 / 750 ||Loss: 0.11228 ||Acc: 96.733%
# Batch  600 / 750 ||Loss: 0.11577 ||Acc: 96.655%
# Train Loss: 0.1161 || Train Acc: 96.616%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.02723 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06629 ||Acc: 98.320%
# val Loss: 0.0623 || val Acc: 98.245%
#
# ==================================================================
# -------------Epoch: 82/100------------
# Batch  0 / 750 ||Loss: 0.21204 ||Acc: 95.312%
# Batch  200 / 750 ||Loss: 0.12270 ||Acc: 96.463%
# Batch  400 / 750 ||Loss: 0.12114 ||Acc: 96.522%
# Batch  600 / 750 ||Loss: 0.11891 ||Acc: 96.539%
# Train Loss: 0.1184 || Train Acc: 96.547%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.02811 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06526 ||Acc: 98.081%
# val Loss: 0.0612 || val Acc: 98.124%
#
# ==================================================================
# -------------Epoch: 83/100------------
# Batch  0 / 750 ||Loss: 0.11808 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.11569 ||Acc: 96.455%
# Batch  400 / 750 ||Loss: 0.12275 ||Acc: 96.392%
# Batch  600 / 750 ||Loss: 0.11966 ||Acc: 96.384%
# Train Loss: 0.1184 || Train Acc: 96.387%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.03494 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06711 ||Acc: 98.094%
# val Loss: 0.0644 || val Acc: 98.101%
#
# ==================================================================
# -------------Epoch: 84/100------------
# Batch  0 / 750 ||Loss: 0.06076 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.10717 ||Acc: 96.731%
# Batch  400 / 750 ||Loss: 0.10802 ||Acc: 96.769%
# Batch  600 / 750 ||Loss: 0.11239 ||Acc: 96.761%
# Train Loss: 0.1145 || Train Acc: 96.754%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.05453 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06564 ||Acc: 97.988%
# val Loss: 0.0648 || val Acc: 98.062%
#
# ==================================================================
# -------------Epoch: 85/100------------
# Batch  0 / 750 ||Loss: 0.12037 ||Acc: 95.312%
# Batch  200 / 750 ||Loss: 0.11086 ||Acc: 96.399%
# Batch  400 / 750 ||Loss: 0.11359 ||Acc: 96.483%
# Batch  600 / 750 ||Loss: 0.11378 ||Acc: 96.500%
# Train Loss: 0.1153 || Train Acc: 96.507%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.08331 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.07042 ||Acc: 98.218%
# val Loss: 0.0676 || val Acc: 98.151%
#
# ==================================================================
# -------------Epoch: 86/100------------
# Batch  0 / 750 ||Loss: 0.14947 ||Acc: 95.312%
# Batch  200 / 750 ||Loss: 0.11785 ||Acc: 96.838%
# Batch  400 / 750 ||Loss: 0.11319 ||Acc: 96.735%
# Batch  600 / 750 ||Loss: 0.11553 ||Acc: 96.713%
# Train Loss: 0.1149 || Train Acc: 96.679%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.05389 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06288 ||Acc: 97.998%
# val Loss: 0.0600 || val Acc: 98.043%
#
# ==================================================================
# -------------Epoch: 87/100------------
# Batch  0 / 750 ||Loss: 0.11698 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.11184 ||Acc: 96.545%
# Batch  400 / 750 ||Loss: 0.11182 ||Acc: 96.615%
# Batch  600 / 750 ||Loss: 0.11565 ||Acc: 96.612%
# Train Loss: 0.1155 || Train Acc: 96.607%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.10002 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06226 ||Acc: 98.319%
# val Loss: 0.0641 || val Acc: 98.305%
#
# ==================================================================
# -------------Epoch: 88/100------------
# Batch  0 / 750 ||Loss: 0.06322 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.10945 ||Acc: 96.566%
# Batch  400 / 750 ||Loss: 0.11125 ||Acc: 96.612%
# Batch  600 / 750 ||Loss: 0.11320 ||Acc: 96.627%
# Train Loss: 0.1157 || Train Acc: 96.629%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.27348 ||Acc: 95.312%
# Batch  100 / 188 ||Loss: 0.06179 ||Acc: 98.207%
# val Loss: 0.0623 || val Acc: 98.231%
#
# ==================================================================
# -------------Epoch: 89/100------------
# Batch  0 / 750 ||Loss: 0.03679 ||Acc: 98.438%
# Batch  200 / 750 ||Loss: 0.11449 ||Acc: 96.382%
# Batch  400 / 750 ||Loss: 0.11948 ||Acc: 96.392%
# Batch  600 / 750 ||Loss: 0.11757 ||Acc: 96.425%
# Train Loss: 0.1173 || Train Acc: 96.444%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.08092 ||Acc: 95.312%
# Batch  100 / 188 ||Loss: 0.06104 ||Acc: 98.250%
# val Loss: 0.0618 || val Acc: 98.248%
#
# ==================================================================
# -------------Epoch: 90/100------------
# Batch  0 / 750 ||Loss: 0.02936 ||Acc: 100.000%
# Batch  200 / 750 ||Loss: 0.10697 ||Acc: 97.177%
# Batch  400 / 750 ||Loss: 0.11113 ||Acc: 96.966%
# Batch  600 / 750 ||Loss: 0.11331 ||Acc: 96.864%
# Train Loss: 0.1132 || Train Acc: 96.823%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.06967 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.06412 ||Acc: 98.359%
# val Loss: 0.0620 || val Acc: 98.284%
#
# ==================================================================
# -------------Epoch: 91/100------------
# Batch  0 / 750 ||Loss: 0.02869 ||Acc: 100.000%
# Batch  200 / 750 ||Loss: 0.10940 ||Acc: 96.891%
# Batch  400 / 750 ||Loss: 0.11234 ||Acc: 96.815%
# Batch  600 / 750 ||Loss: 0.11130 ||Acc: 96.749%
# Train Loss: 0.1122 || Train Acc: 96.730%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.04182 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06609 ||Acc: 98.161%
# val Loss: 0.0616 || val Acc: 98.126%
#
# ==================================================================
# -------------Epoch: 92/100------------
# Batch  0 / 750 ||Loss: 0.03259 ||Acc: 98.438%
# Batch  200 / 750 ||Loss: 0.11278 ||Acc: 96.804%
# Batch  400 / 750 ||Loss: 0.11493 ||Acc: 96.727%
# Batch  600 / 750 ||Loss: 0.11353 ||Acc: 96.715%
# Train Loss: 0.1146 || Train Acc: 96.710%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.09721 ||Acc: 95.312%
# Batch  100 / 188 ||Loss: 0.06201 ||Acc: 97.982%
# val Loss: 0.0626 || val Acc: 98.056%
#
# ==================================================================
# -------------Epoch: 93/100------------
# Batch  0 / 750 ||Loss: 0.17132 ||Acc: 92.188%
# Batch  200 / 750 ||Loss: 0.11082 ||Acc: 96.758%
# Batch  400 / 750 ||Loss: 0.10994 ||Acc: 96.776%
# Batch  600 / 750 ||Loss: 0.11089 ||Acc: 96.762%
# Train Loss: 0.1121 || Train Acc: 96.743%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.17284 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.06544 ||Acc: 98.226%
# val Loss: 0.0613 || val Acc: 98.185%
#
# ==================================================================
# -------------Epoch: 94/100------------
# Batch  0 / 750 ||Loss: 0.08394 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.10836 ||Acc: 96.639%
# Batch  400 / 750 ||Loss: 0.11652 ||Acc: 96.634%
# Batch  600 / 750 ||Loss: 0.11296 ||Acc: 96.618%
# Train Loss: 0.1132 || Train Acc: 96.614%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.06478 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06413 ||Acc: 98.209%
# val Loss: 0.0673 || val Acc: 98.173%
#
# ==================================================================
# -------------Epoch: 95/100------------
# Batch  0 / 750 ||Loss: 0.18877 ||Acc: 95.312%
# Batch  200 / 750 ||Loss: 0.11325 ||Acc: 96.960%
# Batch  400 / 750 ||Loss: 0.11493 ||Acc: 96.827%
# Batch  600 / 750 ||Loss: 0.11369 ||Acc: 96.772%
# Train Loss: 0.1140 || Train Acc: 96.750%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.13518 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.05625 ||Acc: 98.141%
# val Loss: 0.0619 || val Acc: 98.171%
#
# ==================================================================
# -------------Epoch: 96/100------------
# Batch  0 / 750 ||Loss: 0.08068 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.10965 ||Acc: 96.485%
# Batch  400 / 750 ||Loss: 0.11375 ||Acc: 96.578%
# Batch  600 / 750 ||Loss: 0.11452 ||Acc: 96.605%
# Train Loss: 0.1163 || Train Acc: 96.606%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.00510 ||Acc: 100.000%
# Batch  100 / 188 ||Loss: 0.06190 ||Acc: 98.207%
# val Loss: 0.0654 || val Acc: 98.216%
#
# ==================================================================
# -------------Epoch: 97/100------------
# Batch  0 / 750 ||Loss: 0.06819 ||Acc: 98.438%
# Batch  200 / 750 ||Loss: 0.11162 ||Acc: 96.690%
# Batch  400 / 750 ||Loss: 0.11440 ||Acc: 96.671%
# Batch  600 / 750 ||Loss: 0.11645 ||Acc: 96.631%
# Train Loss: 0.1147 || Train Acc: 96.614%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.04353 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.07207 ||Acc: 97.864%
# val Loss: 0.0678 || val Acc: 97.919%
#
# ==================================================================
# -------------Epoch: 98/100------------
# Batch  0 / 750 ||Loss: 0.15982 ||Acc: 96.875%
# Batch  200 / 750 ||Loss: 0.11599 ||Acc: 96.630%
# Batch  400 / 750 ||Loss: 0.11275 ||Acc: 96.652%
# Batch  600 / 750 ||Loss: 0.11297 ||Acc: 96.675%
# Train Loss: 0.1123 || Train Acc: 96.679%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.03767 ||Acc: 96.875%
# Batch  100 / 188 ||Loss: 0.05614 ||Acc: 98.291%
# val Loss: 0.0629 || val Acc: 98.222%
#
# ==================================================================
# -------------Epoch: 99/100------------
# Batch  0 / 750 ||Loss: 0.24434 ||Acc: 92.188%
# Batch  200 / 750 ||Loss: 0.11370 ||Acc: 96.589%
# Batch  400 / 750 ||Loss: 0.11499 ||Acc: 96.592%
# Batch  600 / 750 ||Loss: 0.11392 ||Acc: 96.609%
# Train Loss: 0.1143 || Train Acc: 96.617%
#
# ...........................validation....................................
# Batch  0 / 188 ||Loss: 0.03350 ||Acc: 98.438%
# Batch  100 / 188 ||Loss: 0.06516 ||Acc: 98.063%
# val Loss: 0.0623 || val Acc: 98.112%
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-4435118f4d6b> in <module>
# ----> 1 train_classifier()
#
# <ipython-input-8-6d06674e852e> in train_classifier(**kwargs)
#     162     filepath=os.path.join(opt.save_path, 'classifier_accuracy.png')
#     163     plt.title("Training Curve")
# --> 164     plt.plot(epoches, train_acc, label="Train")
#     165     plt.plot(epoches, val_acc, label="Validation")
#     166     plt.xlabel("Epochs")
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2824     return gca().plot(
#    2825         *args, scalex=scalex, scaley=scaley,
# -> 2826         **({"data": data} if data is not None else {}), **kwargs)
#    2827
#    2828
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# ~/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     397
#     398         if x.shape[0] != y.shape[0]:
# --> 399             raise ValueError(f"x and y must have same first dimension, but "
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (100,) and (1,)

# %%
def test_classifier(**kwargs):
    
    model=Net()
    model.to(device)
    autoencoder=Autoencoder().to(device)
    
    state = torch.load(os.path.join(opt.model_path,'autoencoder.pth'))
    autoencoder.load_state_dict(state['state_dict'])
    print("Loaded pre-trained autoencoder with success.")
    
    state = torch.load(os.path.join(opt.model_path,'classifier.pth'))
    model.load_state_dict(state['state_dict'])
    print("Loaded pre-trained classifier with success.")

    
    model.eval()
    test_acc = 0.0
    v_correct = 0
    v_total = 0
    with torch.no_grad():
        for (image,label) in tqdm(test_loader):
            image, label = image.to(device),label.to(device)
            label=label.squeeze()

            image = image.view(image.size(0),-1)
            dec_out = autoencoder(image)
            dec_out = dec_out.view(dec_out.size(0),1,28,28)
            output = model(dec_out)


            _, predicted = torch.max(output.data, 1)
            v_total += label.size(0)
            v_correct += predicted.eq(label).sum().item()
            test_acc +=100.*v_correct/v_total
        accuracy = test_acc/len(test_loader)
    print('Test Acc: %.3f%%'%(accuracy))

# %%
test_classifier()
# Out:
#   0%|          | 0/157 [00:00<?, ?it/s]
# Loaded pre-trained autoencoder with success.
# Loaded pre-trained classifier with success.
# 100%|██████████| 157/157 [00:02<00:00, 60.03it/s]
# Test Acc: 98.584%
